# %%
import numpy as np
from PIL import Image

# %%
recorded_data = np.load(file="./training_data_2020_Jan_19_13_50_56.npy")

# %%
print(recorded_data[0][2].shape)
# Out:
# (224, 224, 3)

# %%
print(recorded_data[122][2].shape)

print(recorded_data.shape)
# Out:
# (224, 224, 3)
# (175, 3)

# %%
Image.fromarray(recorded_data[70][2],'RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F8A3E8CF8>
